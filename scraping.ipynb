# %%
import requests

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
data = requests.get(standings_url)

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)

# %%
standings_table = soup.select('table.stats_table')[0]

# %%
links = standings_table.find_all('a')

# %%
links = [l.get('href') for l in links]

# %%
links = [l for l in links if '/squads/' in l]

# %%
links
# Out:
# ['/en/squads/822bd0ba/Liverpool-Stats',
#  '/en/squads/18bb7c10/Arsenal-Stats',
#  '/en/squads/e4a775cb/Nottingham-Forest-Stats',
#  '/en/squads/b2b47a98/Newcastle-United-Stats',
#  '/en/squads/cff3d9bb/Chelsea-Stats',
#  '/en/squads/b8fd03ef/Manchester-City-Stats',
#  '/en/squads/8602292d/Aston-Villa-Stats',
#  '/en/squads/4ba7cbea/Bournemouth-Stats',
#  '/en/squads/fd962109/Fulham-Stats',
#  '/en/squads/cd051869/Brentford-Stats',
#  '/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  '/en/squads/7c21e445/West-Ham-United-Stats',
#  '/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  '/en/squads/47c64c55/Crystal-Palace-Stats',
#  '/en/squads/19538871/Manchester-United-Stats',
#  '/en/squads/d3fd31cc/Everton-Stats',
#  '/en/squads/b74092de/Ipswich-Town-Stats',
#  '/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats',
#  '/en/squads/a2d435b3/Leicester-City-Stats',
#  '/en/squads/33c895d4/Southampton-Stats']

# %%
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
data = requests.get(team_urls[0])

# %%
import pandas as pd

# %%
from io import StringIO

# %%
html_data = StringIO(data.text)

# %%
matches = pd.read_html(html_data, match="Scores & Fixtures")[0]

# %%
matches
# Out:
#           Date   Time            Comp                Round  Day Venue Result  \
# 0   2024-08-17  12:30  Premier League          Matchweek 1  Sat  Away      W
# 1   2024-08-25  16:30  Premier League          Matchweek 2  Sun  Home      W
# 2   2024-09-01  16:00  Premier League          Matchweek 3  Sun  Away      W
# 3   2024-09-14  15:00  Premier League          Matchweek 4  Sat  Home      L
# 4   2024-09-17  21:00    Champions Lg         League phase  Tue  Away      W
# 5   2024-09-21  15:00  Premier League          Matchweek 5  Sat  Home      W
# 6   2024-09-25  20:00         EFL Cup          Third round  Wed  Home      W
# 7   2024-09-28  17:30  Premier League          Matchweek 6  Sat  Away      W
# 8   2024-10-02  20:00    Champions Lg         League phase  Wed  Home      W
# 9   2024-10-05  12:30  Premier League          Matchweek 7  Sat  Away      W
# 10  2024-10-20  16:30  Premier League          Matchweek 8  Sun  Home      W
# 11  2024-10-23  21:00    Champions Lg         League phase  Wed  Away      W
# 12  2024-10-27  16:30  Premier League          Matchweek 9  Sun  Away      D
# 13  2024-10-30  19:30         EFL Cup         Fourth round  Wed  Away      W
# 14  2024-11-02  15:00  Premier League         Matchweek 10  Sat  Home      W
# 15  2024-11-05  20:00    Champions Lg         League phase  Tue  Home      W
# 16  2024-11-09  20:00  Premier League         Matchweek 11  Sat  Home      W
# 17  2024-11-24  14:00  Premier League         Matchweek 12  Sun  Away      W
# 18  2024-11-27  20:00    Champions Lg         League phase  Wed  Home      W
# 19  2024-12-01  16:00  Premier League         Matchweek 13  Sun  Home      W
# 20  2024-12-04  19:30  Premier League         Matchweek 14  Wed  Away      D
# 21  2024-12-10  18:45    Champions Lg         League phase  Tue  Away      W
# 22  2024-12-14  15:00  Premier League         Matchweek 16  Sat  Home      D
# 23  2024-12-18  20:00         EFL Cup       Quarter-finals  Wed  Away      W
# 24  2024-12-22  16:30  Premier League         Matchweek 17  Sun  Away      W
# 25  2024-12-26  20:00  Premier League         Matchweek 18  Thu  Home      W
# 26  2024-12-29  17:15  Premier League         Matchweek 19  Sun  Away      W
# 27  2025-01-05  16:30  Premier League         Matchweek 20  Sun  Home      D
# 28  2025-01-08  20:00         EFL Cup          Semi-finals  Wed  Away      L
# 29  2025-01-11  12:15          FA Cup   Third round proper  Sat  Home      W
# 30  2025-01-14  20:00  Premier League         Matchweek 21  Tue  Away      D
# 31  2025-01-18  15:00  Premier League         Matchweek 22  Sat  Away    NaN
# 32  2025-01-21  20:00    Champions Lg         League phase  Tue  Home    NaN
# 33  2025-01-25  15:00  Premier League         Matchweek 23  Sat  Home    NaN
# 34  2025-01-29  21:00    Champions Lg         League phase  Wed  Away    NaN
# 35  2025-02-01  15:00  Premier League         Matchweek 24  Sat  Away    NaN
# 28  Match Report                           Leg 1 of 2
# 29  Match Report                                  NaN
# 30  Match Report                                  NaN
# 31  Head-to-Head                                  NaN
# 32  Head-to-Head                                  NaN
# 33  Head-to-Head                                  NaN
# 34  Head-to-Head                                  NaN
# 35  Head-to-Head                                  NaN
# 36  Head-to-Head  Leg 2 of 2; Tottenham 1:0 Liverpool
# 37  Head-to-Head                                  NaN
# 38  Head-to-Head                                  NaN
# 39  Head-to-Head                                  NaN
# 40  Head-to-Head                                  NaN
# 41  Head-to-Head                                  NaN
# 42  Head-to-Head                                  NaN
# 43  Head-to-Head                                  NaN
# 44  Head-to-Head                                  NaN
# 45  Head-to-Head                                  NaN
# 46  Head-to-Head                                  NaN
# 47  Head-to-Head                                  NaN
# 48  Head-to-Head                                  NaN
# 49  Head-to-Head                                  NaN
# 50  Head-to-Head                                  NaN
# 51  Head-to-Head                                  NaN
# 52  Head-to-Head                                  NaN

# %%
soup = BeautifulSoup(data.text)

# %%
links = soup.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
data = requests.get(f"https://fbref.com{links[0]}")

# %%
html_data = StringIO(data.text)

# %%
shooting = pd.read_html(html_data, match="Shooting")[0]

# %%
shooting.head()
# Out:
#   For Liverpool                                                              \
#            Date   Time            Comp         Round  Day Venue Result   GF
# 0    2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1    2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2    2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3    2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4    2024-09-17  21:00    Champions Lg  League phase  Tue  Away      W  3.0
#
#                          ... Standard               Expected               \
#     GA         Opponent  ...     Dist   FK PK PKatt       xG npxG npxG/Sh
# 0  0.0     Ipswich Town  ...     14.8  0.0  0     0      2.6  2.6    0.15
# 1  0.0        Brentford  ...     13.6  1.0  0     0      2.5  2.5    0.14
# 2  0.0   Manchester Utd  ...     13.4  0.0  0     0      1.8  1.8    0.16
# 3  1.0  Nott'ham Forest  ...     14.9  0.0  0     0      0.9  0.9    0.07
# 4  1.0         it Milan  ...     15.7  1.0  0     0      3.1  3.1    0.14
#
#                Unnamed: 25_level_0
#   G-xG np:G-xG        Match Report
# 0 -0.6    -0.6        Match Report
# 1 -0.5    -0.5        Match Report
# 2  1.2     1.2        Match Report
# 3 -0.9    -0.9        Match Report
# 4 -0.1    -0.1        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns = shooting.columns.droplevel()

# %%
shooting.head()
# Out:
#          Date   Time            Comp         Round  Day Venue Result   GF  \
# 0  2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1  2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2  2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3  2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4  2024-09-17  21:00    Champions Lg  League phase  Tue  Away      W  3.0
#
#     GA         Opponent  ...  Dist   FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  \
# 0  0.0     Ipswich Town  ...  14.8  0.0   0      0  2.6   2.6     0.15  -0.6
# 1  0.0        Brentford  ...  13.6  1.0   0      0  2.5   2.5     0.14  -0.5
# 2  0.0   Manchester Utd  ...  13.4  0.0   0      0  1.8   1.8     0.16   1.2
# 3  1.0  Nott'ham Forest  ...  14.9  0.0   0      0  0.9   0.9     0.07  -0.9
# 4  1.0         it Milan  ...  15.7  1.0   0      0  3.1   3.1     0.14  -0.1
#
#    np:G-xG  Match Report
# 0     -0.6  Match Report
# 1     -0.5  Match Report
# 2      1.2  Match Report
# 3     -0.9  Match Report
# 4     -0.1  Match Report
#
# [5 rows x 26 columns]

# %%
team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")

# %%
team_data.head()
# Out:
#          Date   Time            Comp         Round  Day Venue Result   GF  \
# 0  2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1  2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2  2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3  2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4  2024-09-17  21:00    Champions Lg  League phase  Tue  Away      W  3.0
#
#     GA         Opponent  ...  Opp Formation         Referee  Match Report  \
# 0  0.0     Ipswich Town  ...        4-2-3-1    Tim Robinson  Match Report
# 1  0.0        Brentford  ...          4-4-2  Stuart Attwell  Match Report
# 2  0.0   Manchester Utd  ...        4-2-3-1  Anthony Taylor  Match Report
# 3  1.0  Nott'ham Forest  ...        4-2-3-1  Michael Oliver  Match Report
# 4  1.0         it Milan  ...        4-2-3-1     Espen Eskås  Match Report
#
#    Notes  Sh SoT  Dist   FK PK PKatt
# 0    NaN  18   5  14.8  0.0  0     0
# 1    NaN  19   8  13.6  1.0  0     0
# 2    NaN  11   3  13.4  0.0  0     0
# 3    NaN  14   5  14.9  0.0  0     0
# 4    NaN  23  11  15.7  1.0  0     0
#
# [5 rows x 26 columns]

# %%
shooting.shape
# Out:
# (32, 26)

# %%
years = list(range(2024, 2022, -1))

# %%
years
# Out:
# [2024, 2023]

# %%
all_matches = []

# %%
soup = BeautifulSoup(data.text, "lxml")

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
import time

for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)

        # FIXED: Wrapped data.text in StringIO to address the FutureWarning
        matches = pd.read_html(StringIO(data.text), match="Scores & Fixtures")[0]
        
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")

        # FIXED: Wrapped data.text in StringIO to address the FutureWarning
        shooting = pd.read_html(StringIO(data.text), match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        
        try:
            team_data = matches.merge(
                shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]],
                on="Date"
            )
        except ValueError:
            continue
        
        team_data = team_data[team_data["Comp"] == "Premier League"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(12)

# %%
match_df = pd.concat(all_matches)

# %%
match_df
# Out:
#           Date   Time            Comp         Round  Day Venue Result GF GA  \
# 1   2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W  3  0
# 3   2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W  1  0
# 4   2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W  2  1
# 5   2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5  1
# 6   2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3  1
# ..         ...    ...             ...           ...  ...   ...    ... .. ..
# 36  2024-04-24  20:00  Premier League  Matchweek 29  Wed  Away      L  2  4
# 37  2024-04-27  15:00  Premier League  Matchweek 35  Sat  Away      L  1  5
# 38  2024-05-04  15:00  Premier League  Matchweek 36  Sat  Home      L  1  3
# 39  2024-05-11  15:00  Premier League  Matchweek 37  Sat  Away      L  0  1
# 40  2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      L  0  3
#
#            Opponent  ...  Match Report  Notes    Sh   SoT  Dist   FK PK PKatt  \
# 1           Burnley  ...  Match Report    NaN  17.0   8.0  13.9  0.0  0     0
# 3     Newcastle Utd  ...  Match Report    NaN  14.0   4.0  17.9  0.0  0     0
# 4     Sheffield Utd  ...  Match Report    NaN  29.0   9.0  17.3  2.0  0     1
# 5            Fulham  ...  Match Report    NaN   6.0   4.0  14.8  0.0  1     1
# 6          West Ham  ...  Match Report    NaN  29.0  13.0  16.4  1.0  0     0
# ..              ...  ...           ...    ...   ...   ...   ...  ... ..   ...
# 36   Manchester Utd  ...  Match Report    NaN  10.0   4.0  17.8  1.0  0     0
# 37    Newcastle Utd  ...  Match Report    NaN  15.0   4.0  13.5  0.0  0     0
# 38  Nott'ham Forest  ...  Match Report    NaN  16.0   4.0  18.1  0.0  1     1
# 39          Everton  ...  Match Report    NaN  13.0   1.0  21.0  0.0  0     0
# 40        Tottenham  ...  Match Report    NaN   6.0   1.0  18.0  1.0  0     0
#
#    Season              Team
# 1    2024   Manchester City
# 3    2024   Manchester City
# 4    2024   Manchester City
# 5    2024   Manchester City
# 6    2024   Manchester City
# ..    ...               ...
# 36   2023  Sheffield United
# 37   2023  Sheffield United
# 38   2023  Sheffield United
# 39   2023  Sheffield United
# 40   2023  Sheffield United
#
# [2304 rows x 28 columns]

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df.to_csv("matches.csv")
